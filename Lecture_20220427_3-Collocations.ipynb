# %% [markdown]
# # Выделение коллокаций

# %% [markdown]
# Под коллокацией понимается неслучайное сочетание стоящих рядом слов.
#
# Коллокации текста позволяют выделить сочетания слов, особенные или важные именно для этого текста: особые названия, термины, авторскую лексику.
#
# Рассмотрим несколько методов выделения такой лексики.

# %%
# Загружаем необходимые библиотеки.
from sklearn.feature_extraction.text import CountVectorizer
import re
import pymorphy2
from getnewspaper import getNewsPaper
import math

# %%
# Загружаем новости.
lenta_s=getNewsPaper()
lenta_s.loadArticles("data/lenta2018.txt")

# %%
# Создаем объект морфологического словаря.
morph=pymorphy2.MorphAnalyzer()

# %% [markdown]
# Первым методом, который мы рассмотрим, будет анализ частоты сочетаний. Это самый просто метод выделения коллокаций, который исходит из того, что если сочетание встречается в тексте очень часто, то это не спроста.
#
# Рассмотрим новости за лето 2018 года по отдельности и посчитаем частоты для уни- и биграмм.

# %%
words=" ".join([morph.parse(w[0])[0].normal_form for w in re.findall(r'([А-Яа-яЁё]+(\-[А-Яа-яЁё]+)*)', lenta_s.articles[0])])
counter1=CountVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
# Считаем частоты, видим, что слова не приводились к начальной форме.
res=counter1.fit_transform([words])

# %%
for w, f in counter1.vocabulary_.items():
    if ' ' in w and res[(0,f)]>1:
        print(w, res[(0,f)])
# Out:
# собственный крылатый 2
# крылатый ракета 2
# противокорабельный ракета 2
# ракета м 3
# м комплекс 2
# украина провести 2
# система управление 2
# базирование отмечать 2

# %%
lenta_s.articles[0]
# Out:
# 'Испытанная Украиной первая собственная крылатая ракета создана КБ «Луч» в рамках ОКР «Нептун» на основе российской противокорабельной ракеты 3М24 комплекса Х-35У. Об этом пишет военный блог bmpd, который ведут сотрудники московского Центра анализа стратегий и технологий.«Напомним, что в советский период серийное производство ракет 3М24 (Х-35) планировалось организовать на Харьковском авиационном заводе (нынешнее ХГАПП), так что на Украине имеется, видимо, полный комплект производственно-конструкторской документации на эту ракету, как и ведется производство ее двигателя», — отметили эксперты.Разработчиком противокорабельной ракеты 3М24 комплекса «Уран» выступает головное предприятие АО «Корпорация Тактическое ракетное вооружение» (бывшее ГНПЦ «Звезда-Стрела»), расположенное в подмосковном Королёве.Аналитики, ссылаясь на имеющиеся фото- и видеоматериалы тестов, полагают, что Украина провела бросковые испытания макета ракеты, у которого был отключен турбореактивный двигатель и отсутствовала система управления.По мнению экспертов, основной проблемой Украины при разработке «Нептуна» является «создание системы управления и в первую очередь активной радиолокационной головки самонаведения, компетенции в чем у украинских предприятий отсутствуют практически полностью». По данным bmpd, в настоящее время разработкой подобных систем в инициативном порядке занимается киевское частное ООО «Радионикс». Также новая ракета должна получить систему инерциально-спутниковой коррекции с использованием приемников ГЛОНАСС и GPS, для чего, вероятно, будет «использоваться коммерчески доступная аппаратура американского производства».Материалы по теме00:02 — 30 январяРусская смертьЗачем Россия возрождает сверхзвуковой ракетоносец Ту-160Максимальная дальность стрельбы ракеты «Нептун» составит 280 километров, комплекс планируется к созданию в вариантах наземного, корабельного и авиационного базирования, отмечает bmpd. При этом первоочередное внимание будет уделяться наземному варианту.Первые испытания собственной крылатой ракеты Украина провела 30 января. Ракета наземного базирования, отмечал секретарь Совета национальной безопасности и обороны (СНБО) страны Александр Турчинов, способна поражать наземные и морские цели и стала «еще одним существенным аргументом для сдерживания агрессора».'

# %% [markdown]
# Как видно из результатов, на одной статье метод выдает несколько случайные сочетания, не слишком отражающие смысл текста.
#
# Посчитаем теперь частоты для всех статей за лето 2018 года вместе.

# %%
arts=[]
for art in lenta_s.articles:
    arts.append(" ".join([morph.parse(w[0])[0].normal_form for w in re.findall(r'([А-Яа-яЁё]+(\-[А-Яа-яЁё]+)*)', art)]))
words="\n".join(arts)
counter=CountVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
# Считаем частоты, видим, что слова не приводились к начальной форме.
res_all=counter.fit_transform([words])

# %%
print(list(counter.vocabulary_.keys())[1000:1100])
# Out:
# ['денис', 'полищук', 'участвовать', 'массовый', 'протестный', 'акция', 'евромайдан', 'донбасс', 'ракета-носитель', 'союз', 'спутник', 'стартовать', 'космодром', 'восточный', 'космический', 'прямой', 'трансляция', 'запуск', 'доставить', 'орбита', 'дистанционный', 'зондирование', 'земля', 'канопус-в', 'пуск', 'предыдущий', 'состояться', 'завершиться', 'неудача', 'из-за', 'неполадка', 'разгонный', 'блок', 'утерять', 'б', 'борт', 'госкорпорация', 'роскосмос', 'объяснить', 'ошибка', 'программный', 'обеспечение', 'заложить', 'вице-премьер', 'рогозин', 'заявить', 'подготовка', 'перепутать', 'запускать', 'параметр', 'траектория', 'рассчитать', 'учёт', 'старт', 'байконур', 'ставить', 'задача', 'повысить', 'доля', 'успешный', 'полиция', 'торонто', 'ландшафтный', 'дизайнер', 'убивать', 'прятать', 'тело', 'цветочный', 'горшок', 'клумба', 'там', 'где', 'брюс', 'макартур', 'общий', 'сложность', 'жертва', 'мы', 'уверить', 'большой', 'понятие', 'насколько', 'расследование', 'хэнк', 'идсинга', 'территория', 'вывезти', 'растение', 'конец', 'маньяк', 'чарльз', 'мэнсон', 'умереть', 'тюрьмелегендарный', 'убийца', 'дождаться', 'великий', 'межрасовый', 'войныпервоначально', 'считаться']

# %%
#Попробуем сэкономить память для действий ниже.
arts=[]

# %%
# %%time

# В этой ячейке мы просто конвертируем словари в читаемый формат и сортируем по частоте
bigramms=[]
collocations=[]
unigramms={}
for w, f in counter.vocabulary_.items():
    if ' ' in w and res_all[(0,f)]>100:
        bigramms.append("{:7} {}".format(res_all[(0,f)], w))
        collocations.append([w, res_all[(0,f)]])
        #print(w, res_all[(0,f)])
    elif not ' ' in w:
        unigramms[w]=res_all[(0,f)]
# Out:
# CPU times: user 1min 28s, sys: 4.06 ms, total: 1min 28s
# Wall time: 1min 28s

# %%
print(sorted(bigramms, reverse=True)[:200])
# Out:
# ['   1012 о это', '    871 по тема', '    868 материал по', '    572 в год', '    436 один из', '    339 это сообщать', '    265 а также', '    262 что в', '    260 в россия', '    251 по слово', '    238 это в', '    235 в время', '    234 в тот', '    233 заявить что', '    224 год в', '    212 при это', '    212 лента ру', '    205 он слово', '    201 в пхенчхан', '    187 отметить что', '    187 в свой', '    184 игра в', '    182 тот что', '    167 на сайт', '    165 в который', '    162 по данные', '    161 олимпийский игра', '    154 по он', '    153 февраль в', '    153 в результат', '    146 участие в', '    146 сообщаться что', '    146 в частность', '    139 не быть', '    138 и в', '    132 в конец', '    131 российский спортсмен', '    129 что он', '    128 в январь', '    126 сообщить что', '    124 ссылка на', '    121 в это', '    121 в отношение', '    119 тот число', '    119 тот как', '    119 владимир путин', '    116 с ссылка', '    116 президент россия', '    115 на олимпиада', '    114 олимпиада в', '    114 говориться в', '    113 в декабрь', '    111 на который', '    111 который быть', '    110 олимпийский комитет', '    109 то что', '    109 и не', '    108 стать известно', '    108 риа новость', '    108 в сирия', '    105 россия в', '    105 о тот', '    105 новость в', '    104 что это', '    104 тема декабрь', '    104 известно что', '    104 в ход', '    103 не мочь', '    102 находиться в', '    102 кроме тот', '    101 февраль сообщать', '    101 должный быть']

# %%
print(sorted([(w, f) for w, f in unigramms.items()], key=lambda x: x[1], reverse=True)[:200])
# Out:
# [('в', 14675), ('и', 6797), ('на', 5869), ('что', 3714), ('по', 3617), ('с', 3457), ('он', 2780), ('это', 2581), ('не', 2576), ('о', 2390), ('год', 2371), ('быть', 2320), ('который', 1770), ('из', 1665), ('они', 1533), ('февраль', 1420), ('россия', 1312), ('она', 1284), ('за', 1255), ('к', 1213), ('для', 1136), ('как', 1041), ('тот', 955), ('материал', 944), ('а', 929), ('тема', 922), ('российский', 899), ('от', 889), ('свой', 845), ('также', 775), ('один', 708), ('у', 704), ('сообщать', 687), ('человек', 686), ('я', 675), ('до', 668), ('слово', 655), ('время', 652), ('стать', 631), ('после', 622), ('но', 587), ('мочь', 575), ('сша', 573), ('январь', 567), ('заявить', 565), ('этот', 560), ('мы', 548), ('президент', 536), ('весь', 528), ('при', 518), ('страна', 501), ('компания', 480), ('новый', 478), ('тысяча', 469), ('сообщить', 465), ('всё', 461), ('два', 456), ('игра', 447), ('олимпийский', 436), ('украина', 434), ('первый', 426), ('такой', 425), ('более', 412), ('день', 408), ('процент', 406), ('под', 397), ('другой', 391), ('так', 381), ('отметить', 381), ('американский', 377), ('издание', 374), ('дело', 374), ('рассказать', 358), ('суд', 356), ('несколько', 352), ('доллар', 349), ('миллион', 349), ('спортсмен', 348), ('получить', 344), ('глава', 344), ('ранее', 342), ('однако', 340), ('чтобы', 339), ('место', 339), ('опубликовать', 337), ('сообщаться', 333), ('сказать', 330), ('самолёт', 328), ('мужчина', 327), ('себя', 327), ('лента', 325), ('большой', 316), ('олимпиада', 315), ('декабрь', 304), ('только', 303), ('из-за', 302), ('результат', 300), ('уже', 298), ('решение', 298), ('рубль', 296), ('то', 296), ('находиться', 295), ('мир', 287), ('или', 287), ('видео', 285), ('когда', 284), ('же', 284), ('женщина', 283), ('город', 279), ('принять', 278), ('представитель', 278), ('данные', 277), ('пользователь', 272), ('должный', 271), ('работа', 270), ('канал', 268), ('ещё', 262), ('россиянин', 261), ('комитет', 252), ('москва', 250), ('участие', 249), ('летний', 249), ('военный', 248), ('около', 246), ('отношение', 238), ('часть', 236), ('информация', 230), ('раз', 229), ('бывший', 228), ('ребёнок', 228), ('область', 227), ('пхенчхан', 227), ('система', 226), ('произойти', 226), ('организация', 225), ('сайт', 223), ('если', 222), ('дом', 222), ('международный', 220), ('сотрудник', 218), ('новость', 218), ('ру', 218), ('государство', 215), ('помощь', 213), ('владимир', 213), ('агентство', 212), ('где', 212), ('сеть', 208), ('дать', 208), ('самый', 207), ('есть', 207), ('район', 206), ('число', 205), ('сирия', 202), ('последний', 199), ('миллиард', 199), ('житель', 199), ('сделать', 198), ('полиция', 198), ('через', 195), ('конец', 195), ('чем', 194), ('отмечать', 194), ('сам', 194), ('добавить', 193), ('назвать', 191), ('наш', 189), ('мокнуть', 189), ('правительство', 188), ('три', 185), ('путин', 185), ('группа', 185), ('провести', 184), ('член', 184), ('без', 184), ('украинский', 183), ('запретить', 180), ('власть', 178), ('являться', 177), ('обнаружить', 177), ('хороший', 177), ('сторона', 177), ('лидер', 176), ('писать', 175), ('ракета', 174), ('иметь', 174), ('оказаться', 174), ('начало', 174), ('безопасность', 172), ('говориться', 171), ('случай', 171), ('работать', 169), ('считать', 168), ('некоторый', 168), ('написать', 168), ('настоящий', 167), ('смочь', 166), ('сила', 166), ('источник', 164), ('жизнь', 164)]

# %% [markdown]
# Как видно из вывода, метод дает не слишком чистые результаты.
#
# Обратите внимание на распределение частот в отдельных словах и парах. Такое распределение называется [распределением Ципфа](https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%BA%D0%BE%D0%BD_%D0%A6%D0%B8%D0%BF%D1%84%D0%B0) и является характерным практически для любого распределения частот слов и их комбинаций в текстах на любом естественном языке.
#
# $p_i=\frac{p_0}{\beta^{-\alpha*i}}$, где $\alpha\approx1$.
#
# Следом рассмотрим еще одну формулу для определения коллокаций:
#
# $MI(x,y)=\log{\frac{p(x,y)*n}{p(x)p(y)}}$, где $p(x)$ и $p(y)$ - это частоты встречаемости терминов $x$ и $y$, соответственно, $p(xy)$ - частота их совместной встречаемости, а $n$ - размер корпуса.
#
# Но так как логарифм и умножение на константу не влияют на итоговое ранжирование коллокаций, то на практике используют формулу
#
# $PMI(x, y)=\frac{p(x,y)}{p(x)p(y)}$.

# %%
for c in collocations:
    pair=c[0].split(" ")
    c.append(c[1]/(unigramms[pair[0]]*unigramms[pair[1]]))

# %%
unigramms['принц'],unigramms['гарри']
# Out:
# (16, 2)

# %%
print(sorted(collocations, key=lambda x: x[2], reverse=True)[:200])
# Out:
# [['риа новость', 108, 0.004545071963639425], ['владимир путин', 119, 0.0030199213297804847], ['лента ру', 212, 0.0029922371206774876], ['стать известно', 108, 0.0012225492415666743], ['олимпийский комитет', 110, 0.00100116499199068], ['кроме тот', 102, 0.0008683437619716511], ['олимпийский игра', 161, 0.0008260985571496008], ['тот число', 119, 0.0006078406333801558], ['российский спортсмен', 131, 0.00041872834439287586], ['тема декабрь', 104, 0.00037104692316474483], ['один из', 436, 0.00036986138681053936], ['а также', 265, 0.0003680683357061009], ['с ссылка', 116, 0.00026631036176885176], ['по тема', 871, 0.00026117928293542726], ['материал по', 868, 0.0002542138582869032], ['известно что', 104, 0.0002000153857989076], ['это сообщать', 339, 0.00019118550238643496], ['ссылка на', 124, 0.00016768222595450402], ['президент россия', 116, 0.00016495267564615944], ['о это', 1012, 0.00016405694007868898], ['по данные', 162, 0.00016169133124864635], ['должный быть', 101, 0.00016064384781778852], ['при это', 212, 0.0001585689303628087], ['отметить что', 187, 0.00013215230164080862], ['на сайт', 167, 0.0001275990669222723], ['тот как', 119, 0.00011969964442164451], ['сообщаться что', 146, 0.0001180501988256431], ['он слово', 205, 0.00011258169037289253], ['заявить что', 233, 0.00011103645140844735], ['по слово', 251, 0.00010594584099259856], ['февраль сообщать', 101, 0.00010353240256678352], ['то что', 109, 9.915003856845537e-05], ['сообщить что', 126, 7.295846578769086e-05], ['не мочь', 103, 6.953821226032947e-05], ['в частность', 146, 6.76795420041952e-05], ['на олимпиада', 115, 6.220469672505794e-05], ['в пхенчхан', 201, 6.033816388865958e-05], ['в ход', 104, 5.669505962521295e-05], ['тот что', 182, 5.131284766568834e-05], ['в конец', 132, 4.61276372690342e-05], ['о тот', 105, 4.6003198317597316e-05], ['говориться в', 114, 4.5428733674048834e-05], ['участие в', 146, 3.995539226753693e-05], ['в сирия', 108, 3.643294482770253e-05], ['в результат', 153, 3.475298126064736e-05], ['в отношение', 121, 3.4644181352268335e-05], ['новость в', 105, 3.282121813606739e-05], ['игра в', 184, 2.804995636249995e-05], ['который быть', 111, 2.7030976037405026e-05], ['в декабрь', 113, 2.532950775576078e-05], ['олимпиада в', 114, 2.4661312565912226e-05], ['в время', 235, 2.456078009218131e-05], ['находиться в', 102, 2.356134322755753e-05], ['не быть', 139, 2.325846005568644e-05], ['в тот', 234, 1.6696843476011666e-05], ['в год', 572, 1.643941522240991e-05], ['в январь', 128, 1.538327489491601e-05], ['по он', 154, 1.5315367280408464e-05], ['в свой', 187, 1.5080189107184259e-05], ['в россия', 260, 1.350396808908464e-05], ['что он', 129, 1.249404353738334e-05], ['что это', 104, 1.0849342894942684e-05], ['на который', 111, 1.0685272517767875e-05], ['февраль в', 153, 7.342179139573386e-06], ['год в', 224, 6.437812954230455e-06], ['в который', 165, 6.352322928998354e-06], ['это в', 238, 6.283633445035039e-06], ['и не', 109, 6.225344210132896e-06], ['россия в', 105, 5.453525574438027e-06], ['что в', 262, 4.80707924983877e-06], ['в это', 121, 3.1946203649127716e-06], ['и в', 138, 1.3835144726391215e-06]]

# %% [markdown]
# Еще одной формулой является
#
# $t-score(x, y)=\frac{p(x,y)-\frac{f(x)f(y)}{n}}{\sqrt{p(x,y)}}$

# %%
textlen=sum(unigramms.values())
textlen
# Out:
# 285100

# %%
for c in collocations:
    pair=c[0].split(" ")
    c.append((c[1]-(unigramms[pair[0]]*unigramms[pair[1]])/textlen)/math.sqrt(c[1]))
    
print(sorted(collocations, key=lambda x: x[3], reverse=True)[:200])
# Out:
226e-05, 9.158493549378617], ['в декабрь', 113, 2.532950775576078e-05, 9.158120580173126], ['новость в', 105, 3.282121813606739e-05, 9.151878609392323], ['в январь', 128, 1.538327489491601e-05, 8.734069305768154], ['находиться в', 102, 2.356134322755753e-05, 8.596007049204276], ['что он', 129, 1.249404353738334e-05, 8.169256477030375], ['на который', 111, 1.0685272517767875e-05, 7.077226306196685], ['что это', 104, 1.0849342894942684e-05, 6.901061271738009], [' ...

# %% [markdown]
# Наконец, можно использовать формулу странности, требующей дополнительного корпуса текстов другой предметной области.
#
# $wirdness(x)=\frac{p_{main}(x)}{p_{contr}(x)}$
#
# Здесь мы будем считать, что если слово не встретилось в контрастивной корпусе, то его частота все равно равна единице.
#
# Плюсом метода является то, что рассчитывать странность можно для сочетаний произвольной длины.
#
# В качестве контрастивной коллекции будем использовать корпус научных статей по архитектуре с сайта Киберленинка.
#
# !!! **Не забудьте заменить пути к файлу.** !!!
#
# !!! **Обратите внмание, что частоты по контрастивному корпусу считаются больше часа.** !!!

# %%
# Загружаем научные статьи.
with open("/home/edward/projects/TEST/getRusCorpora/Python/all_cyberleninka_archi2.txt") as infile:
    cyber=infile.read()

# %%
# Считаем частоты уни- и биграмм.
words_cyber=" ".join([morph.parse(w[0])[0].normal_form for w in re.findall(r'([А-Яа-яЁё]+(\-[А-Яа-яЁё]+)*)', cyber)])
counter_cyber=CountVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
# Считаем частоты, видим, что слова не приводились к начальной форме.
res_all_cyber=counter_cyber.fit_transform([words_cyber])

# %%
# Пытаемсяя экономить память.
words_cyber=""

# %%
# %%time

# Конвертируем в более удобный формат.
bigramms_cyber={w:res_all_cyber[(0,f)] for w, f in counter_cyber.vocabulary_.items() if ' ' in w}
unigramms_cyber={w:res_all_cyber[(0,f)] for w, f in counter_cyber.vocabulary_.items() if not ' ' in w}
# Out:
# CPU times: user 1h 16min 8s, sys: 1.76 s, total: 1h 16min 10s
# Wall time: 1h 16min 10s

# %%
# %%time

# Рассчитываем значение странности для уни- и биграмм.
collocations_cyber=[[w, res_all[(0,f)]/bigramms_cyber.get(w, 1)]
                     for w, f in counter.vocabulary_.items()
                     if ' ' in w and res_all[(0,f)]>100]
collocations_cyber2=[[w, res_all[(0,f)]/unigramms_cyber.get(w, 1)]
                     for w, f in counter.vocabulary_.items()
                     if not ' ' in w]
# Out:
# CPU times: user 2min 47s, sys: 0 ns, total: 2min 47s
# Wall time: 2min 47s

# %%
print(sorted(collocations_cyber, key=lambda x: x[1], reverse=True)[:200])
# Out:
# [['это сообщать', 2887.0], ['лента ру', 994.0], ['владимир путин', 914.0], ['дональд трамп', 762.0], ['риа новость', 761.0], ['уголовный дело', 585.0], ['рассказать что', 568.0], ['сборный россия', 527.0], ['россия владимир', 492.0], ['сша дональд', 487.0], ['глава государство', 473.0], ['сообщаться на', 434.0], ['в вторник', 434.0], ['инцидент произойти', 415.0], ['в понедельник', 399.0], ['это сообщить', 391.0], ['на чемпионат', 362.0], ['президент сша', 361.5], ['сказать он', 359.0], ['в интервью', 345.0], ['следственный комитет', 344.0], ['она слово', 336.0], ['это сообщаться', 324.0], ['сообщать издание', 322.0], ['на видео', 313.0], ['в матч', 312.0], ['в пресс-релиз', 307.0], ['сообщить в', 284.0], ['он слово', 278.4], ['сборная россия', 278.0], ['в полиция', 270.0], ['прима лента', 262.0], ['сообщать риа', 260.0], ['ким чен', 259.0], ['признаться что', 256.0], ['групповой этап', 250.0], ['сообщать тасс', 247.0], ['американский лидер', 242.0], ['сообщаться что', 230.6], ['возбудить уголовный', 230.0], ['свой страница', 229.0], ['в соцсеть', 226.0], ['в пятница', 223.5], ['июль сообщаться', 223.0], ['статья ук', 220.0], ['корреспондент лента', 219.0], ['пошлина на', 219.0], ['сообщать по', 217.0], ['рассказать в', 217.0], ['продлиться до', 210.0], ['в четверг', 209.5], ['северный поток', 202.0], ['слово приводить', 201.0], ['национальный команда', 197.0], ['президент украина', 195.0], ['ранее сообщаться', 194.0], ['российский лидер', 193.0], ['он добавить', 186.0], ['в пресс-служба', 184.0], ['июнь сообщаться', 182.0], ['финал чемпионат', 180.0], ['повышение пенсионный', 180.0], ['фото опубликовать', 179.0], ['информация издание', 177.0], ['северный корея', 175.0], ['добавить он', 172.0], ['задержать в', 172.0], ['президент владимир', 171.0], ['он заявить', 171.0], ['заявить что', 168.36363636363637], ['путин и', 167.0], ['в правоохранительный', 167.0], ['андрей воробьев', 166.0], ['сотрудник полиция', 165.0], ['свой аккаунт', 164.0], ['публикация от', 163.0], ['вторник июль', 163.0], ['август сообщаться', 163.0], ['сообщать с', 161.0], ['главный тренер', 159.0], ['пользователь сеть', 159.0], ['сыграть с', 159.0], ['сообщать интерфакс', 159.0], ['в аккаунт', 158.0], ['с команда', 157.0], ['данные издание', 157.0], ['передавать риа', 156.0], ['право человек', 156.0], ['подозревать в', 155.0], ['путин в', 154.0], ['завершиться с', 152.0], ['сообщать корреспондент', 151.0], ['комитет россия', 151.0], ['с президент', 150.0], ['он рассказать', 149.0], ['пенсионный возраст', 149.0], ['обвинение в', 147.0], ['четверг август', 147.0], ['напасть на', 146.0], ['ук рф', 144.0], ['передавать тасс', 144.0], ['понедельник июль', 144.0], ['ранее август', 143.0], ['пятница июнь', 142.0], ['дмитрий медведев', 141.0], ['видео с', 141.0], ['пресс-релиз на', 139.0], ['дмитрий песок', 139.0], ['версия следствие', 139.0], ['сайт региональный', 139.0], ['санкция в', 139.0], ['ранее июль', 139.0], ['среда август', 139.0], ['лига чемпион', 137.0], ['сообщить что', 136.0], ['в вконтакте', 136.0], ['среда июнь', 136.0], ['мегана марклый', 135.0], ['редакция лента', 134.0], ['четверг июнь', 134.0], ['министр иностранный', 133.0], ['с счёт', 133.0], ['пятница август', 133.0], ['пятница июль', 132.0], ['год лишение', 131.0], ['июль сообщать', 129.0], ['вторник август', 129.0], ['заявить он', 128.0], ['июнь сообщать', 128.0], ['официальный представитель', 127.0], ['нападать сборный', 127.0], ['мужчина в', 126.0], ['он подчеркнуть', 125.0], ['год сообщаться', 124.0], ['сообщить издание', 124.0], ['предъявить обвинение', 124.0], ['среда июль', 124.0], ['понедельник июнь', 123.0], ['в четвертьфинал', 123.0], ['матч в', 123.0], ['это заявить', 122.5], ['летний мужчина', 122.0], ['чен ын', 121.0], ['матч финал', 121.0], ['это говориться', 119.66666666666667], ['санкция против', 119.0], ['сборный хорватия', 119.0], ['в заявление', 119.0], ['пять поколение', 118.0], ['в колония', 118.0], ['пётр порошенко', 118.0], ['федерация футбол', 118.0], ['собеседник аг ...

# %%
print(sorted(collocations_cyber2, key=lambda x: x[1], reverse=True)[:200])
# Out:
# [['футболист', 818.0], ['дональд', 775.0], ['вторник', 445.0], ['пошлина', 432.0], ['интерфакс', 423.0], ['арестовать', 413.0], ['соцсеть', 386.0], ['истребитель', 346.0], ['жительница', 342.0], ['тасс', 341.0], ['порошенко', 337.0], ['пенсионный', 332.0], ['актриса', 327.0], ['пообещать', 320.0], ['роналда', 311.0], ['пресс-секретарь', 304.0], ['собеседник', 303.0], ['полузащитник', 302.0], ['сексуальный', 296.0], ['трамп', 279.5], ['боевик', 278.0], ['пенальти', 277.0], ['мундиаля', 274.0], ['игрок', 267.0], ['форвард', 252.0], ['аккаунт', 251.5], ['боец', 248.0], ['украинец', 247.0], ['спецслужба', 242.0], ['рэпер', 234.0], ['сериал', 227.0], ['смартфон', 226.0], ['напасть', 218.0], ['наркотик', 218.0], ['пожаловаться', 215.0], ['телеканал', 212.66666666666666], ['вконтакте', 207.0], ['вице-премьер', 205.0], ['адвокат', 198.5], ['чечня', 196.0], ['четвертьфинал', 189.0], ['россиянка', 185.0], ['хорват', 184.0], ['пресс-служба', 183.66666666666666], ['авиакомпания', 183.5], ['марклый', 183.0], ['преступник', 181.0], ['пытка', 177.0], ['ювентус', 177.0], ['алкоголь', 176.0], ['приговорить', 176.0], ['сенцов', 174.0], ['гражданство', 172.0], ['днр', 167.0], ['сбу', 166.0], ['блогер', 165.0], ['поединок', 164.0], ['убийство', 162.5], ['фигурант', 162.0], ['коммерсантъ', 160.0], ['мегана', 160.0], ['кардашьян', 159.0], ['взятка', 156.0], ['обыск', 155.0], ['парень', 155.0], ['анкара', 155.0], ['португалец', 154.0], ['британец', 154.0], ['комментатор', 152.0], ['роскосмос', 152.0], ['гарри', 152.0], ['хорватия', 151.0], ['секс', 150.0], ['журналистка', 150.0], ['попросить', 148.33333333333334], ['солсбери', 148.0], ['выплатить', 145.0], ['путин', 143.63636363636363], ['обвинение', 141.8], ['уильямс', 141.0], ['покушение', 140.0], ['продюсер', 140.0], ['хакер', 140.0], ['силовик', 140.0], ['плей-офф', 138.0], ['спросить', 137.0], ['изнасилование', 137.0], ['признаться', 134.33333333333334], ['прокомментировать', 134.0], ['американка', 132.0], ['домогательство', 132.0], ['нападать', 130.4], ['юрист', 130.0], ['подруга', 129.0], ['вратарь', 129.0], ['прокурор', 128.0], ['певица', 126.5], ['насилие', 125.0], ['бабченко', 125.0], ['выборы', 125.0], ['избить', 125.0], ['криштиан', 124.0], ['активист', 122.0], ['макгрегор', 122.0], ['пресс-конференция', 121.0], ['пьяный', 118.0], ['артистка', 117.0], ['герцогиня', 117.0], ['спортсменка', 116.0], ['боксёрский', 116.0], ['девушка', 115.9], ['украсть', 115.0], ['поведать', 115.0], ['референдум', 115.0], ['мошенник', 115.0], ['крокодил', 115.0], ['меркель', 114.0], ['северокорейский', 112.0], ['месси', 112.0], ['законопроект', 110.33333333333333], ['нелегальный', 110.0], ['фсин', 110.0], ['пресс-релиз', 109.66666666666667], ['оскорбление', 108.0], ['нервно-паралитический', 108.0], ['экстремистский', 108.0], ['четверг', 107.0], ['неймара', 107.0], ['мэй', 107.0], ['нато', 106.5], ['мессенджер', 104.0], ['цар', 104.0], ['допрос', 103.0], ['аргентинец', 103.0], ['мужчина', 100.21739130434783], ['сняться', 99.0], ['беспилотник', 98.0], ['авиабаза', 98.0], ['парламентарий', 98.0], ['свадьба', 97.5], ['макрон', 97.0], ['рассказать', 96.46153846153847], ['скрипалить', 95.0], ['рамзан', 95.0], ['тренер', 94.4], ['скрипаль', 94.0], ['черчёс', 94.0], ['послематчевый', 94.0], ['полиция', 93.53333333333333], ['черчесова', 93.0], ['извиниться', 93.0], ['голодовка', 91.0], ['договориться', 90.5], ['хавбек', 90.0], ['уголовный', 89.77777777777777], ['ына', 89.0], ['денуклеаризация', 89.0], ['дерипаск', 89.0], ['уэст', 89.0], ['пошутить', 88.0], ['коалиция', 88.0], ['нафтогаз', 87.0], ['застрелить', 86.0], ['миллиардер', 86.0], ['опьянение', 86.0], ['рептилия', 86.0], ['арестованный', 85.0], ['госпитализировать', 85.0], ['оштрафовать', 85.0], ['проголосовать', 85.0], ['мем', 85.0], ['похитить', 84.5], ['пхеньян', 84.0], ['связаться', 84.0], ['твит', 84.0], ['пилот', 84.0], ['отметиться', 84.0], ['топ-менеджер', 84.0], ['экстремизм', 84.0], ['журналист', 83.83333333333333], ['купальник', 83.0], ['антироссий ...

# %%
print(sorted(collocations_cyber, key=lambda x: x[1], reverse=True)[-200:])
# Out:
# [['к она', 0.30547550432276654], ['они мочь', 0.3037249283667622], ['с такой', 0.30158730158730157], ['с сторона', 0.30068337129840544], ['год для', 0.29549902152641877], ['апрель год', 0.29329173166926675], ['несмотря на', 0.29283276450511947], ['на этот', 0.29198966408268734], ['что с', 0.2917981072555205], ['кроме тот', 0.2896440129449838], ['в частность', 0.28891605541972293], ['и он', 0.28830151737640725], ['в год', 0.2861279059865452], ['но не', 0.2782608695652174], ['в другой', 0.2718600953895072], ['дом на', 0.26973684210526316], ['в три', 0.26862745098039215], ['тем не', 0.2670250896057348], ['не иметь', 0.26666666666666666], ['в второе', 0.2665198237885463], ['роль в', 0.2647058823529412], ['же время', 0.26423487544483987], ['это мочь', 0.26097560975609757], ['период с', 0.2597701149425287], ['однако в', 0.2593939393939394], ['тот число', 0.25892857142857145], ['свой очередь', 0.25541516245487367], ['раз в', 0.25524475524475526], ['на она', 0.255], ['но в', 0.25442834138486314], ['в середина', 0.2531914893617021], ['работать на', 0.2525879917184265], ['большой чем', 0.25241157556270094], ['на три', 0.2524084778420039], ['находиться в', 0.250733615911314], ['и она', 0.2505175983436853], ['в немой', 0.24849939975990396], ['с они', 0.2467718794835007], ['год быть', 0.2459954233409611], ['который должный', 0.24299065420560748], ['в тот', 0.24035755669591